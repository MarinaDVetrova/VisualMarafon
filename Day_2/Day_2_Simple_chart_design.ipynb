# %%
import matplotlib.pyplot as plt
import numpy as np

plt.plot([1, 2, -6, 0, 4])

plt.show()

# %% [markdown]
# ### Оформление

# %% [markdown]
# Добавим простой график.

# %%
x = np.array([4, 5, 6, 7, 8])
y = np.array([1, 2, -6, 0, 4])
plt.plot(x, y)

# %% [markdown]
# #### Линии

# %% [markdown]
#    Обозначение типа линии | Описание
# :------------------------:| :-------------:
#                  '-'      | Непрерывная линия (используется по умолчанию)
#                  '--'     | Штриховая линия
#                  '-.'     | Штрихпунктирная линия
#                  ':'      | Пунктирная линия
#           'None' или ' '  | Без рисования линии

# %%
plt.plot(x, y, '-.')
